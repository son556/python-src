# %%
Jupyter Notebook
day_1.py
3분 전
Python
File
Edit
View
Language
1
#!/usr/bin/env python
2
# coding: utf-8
3
​
4
# # python
5
# ## 기본문법 1일차
6
​
7
# In[ ]:
8
​
9
​
10
print('hello')
11
print(10*20)
12
10+20
13
​
14
​
15
# In[ ]:
16
​
17
​
18
import keyword
19
#print(keyword.kwlist)
20
​
21
​
22
# In[ ]:
23
​
24
​
25
1 + 1
26
​
27
​
28
# In[ ]:
29
​
30
​
31
'hello'+' test'
32
​
33
​
34
# In[ ]:
